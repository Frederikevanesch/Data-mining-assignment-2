# %%
# TODO: Try optuna to optimize the hyperparameters, as GridSearch is not that good at this task

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import ndcg_score
import xgboost as xgb
from itertools import product

# %%
# File path
file_path = 'df_OptionB.csv'
# Read the dataset using pandas
balanced_df = pd.read_csv(file_path)

# %%
# Create a balanced dataset:
def balanced_data(x, id_col):
    """
    The function creates a balanced sample DF.
    It resamples the majority class to have the same number of instances as the minority class, resulting in a balanced dataset.

    Input:
    x: DataFrame
    id_col: column which would be used for ranking on
    
    Output:
    Balanced DataFrame sample
    """
    
    # Create a sample DataFrame with instances where id_col is 1 (clicked hotels):
    click_indices = x[x[id_col] == 1].index
    random_indices = np.random.choice(click_indices, len(x.loc[x[id_col] == 1]), replace=False)
    click_sample = x.loc[random_indices]

    # Create a sample DataFrame with instances where id_col is 0 (non-clicked hotels):
    not_click_indices = x[x[id_col] == 0].index
    random_indices = np.random.choice(not_click_indices, sum(x[id_col]), replace=False)
    not_click_sample = x.loc[random_indices]

    # Concatenate the two sampled DataFrames and create a balanced DataFrame
    df_balanced = pd.concat([not_click_sample, click_sample], axis=0)

    return df_balanced

# %%
# balanced_df = balanced_data(df, 'click_bool')

# %%
# Test if set is balanced:
print("Non-click impressions: ", len(balanced_df[balanced_df['click_bool'] == 0]))
print("Click impression: ", len(balanced_df[balanced_df['click_bool'] == 1]))
print("Total number of records in resampled data: ", len(balanced_df))
# Out:
# Non-click impressions:  4736468
# Click impression:  221879
# Total number of records in resampled data:  4958347

# %%
balanced_df.columns
# Out:
# Index(['srch_id', 'prop_id', 'prop_starrating', 'prop_review_score',
#        'prop_brand_bool', 'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'price_usd', 'promotion_flag',
#        'srch_length_of_stay', 'srch_booking_window', 'srch_adults_count',
#        'srch_room_count', 'srch_saturday_night_bool',
#        'orig_destination_distance', 'click_bool', 'booking_bool', 'score',
#        'avg_comp_rate', 'avg_comp_inv', 'abroad_bool', 'children_bool',
#        'srch_query_affinity_score_low', 'srch_query_affinity_score_high',
#        'starrating_diff_low', 'starrating_diff_high', 'usd_diff_low',
#        'usd_diff_high'],
#       dtype='object')

# %%
# Drop target variable and save it in separate variable
y = balanced_df['score']
X = balanced_df.drop(['score'], axis=1)

# Perform group based split
gss = GroupShuffleSplit(test_size=0.3, n_splits=1, random_state=42)
train_idx, test_idx = next(gss.split(X, y, groups=X['srch_id']))

# Create train and test sets
X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
X_test, y_test = X.iloc[test_idx], y.iloc[test_idx]

# Create group data
group_train = list(X_train['srch_id'].value_counts().sort_index())
group_test = list(X_test['srch_id'].value_counts().sort_index())

# Drop unwanted columns
X_train = X_train.drop(['click_bool', 'booking_bool', 'srch_id', 'prop_id'], axis=1)
X_test = X_test.drop(['click_bool', 'booking_bool', 'srch_id', 'prop_id'], axis=1)

# %% [markdown]
# # Applying XGBRanker

# %% [markdown]
# ##### Hyperparameter tuning for XGRanker

# %% [markdown]
# ### NEXT TWO CELLS HAVE TO BE CHANGED

# %%
params = {
    'objective' : 'rank:ndcg',
    'booster' : 'gbtree',
    'tree_method' : 'auto',
    'random_state' : 42,
    'learning_rate' : 0.01,
    'colsample_bytree' : 0.9,
    'n_estimators' : 100,
    'subsample' : 0.8,
    'reg_alpha': 1e-5,
    'reg_lambda': 1e-5
}

# fit model:
tester  = xgb.XGBRanker(**params)
# fit each model with unique combination of hyperparameters
tester.fit(X_train, y_train, group=group_train,
           eval_set=[(X_test, y_test)], eval_group=[group_test],
             eval_metric='ndcg',early_stopping_rounds = 10, verbose=True)
# Out:
# c:\Users\Asus\anaconda3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-ndcg:0.42244
# [1]	validation_0-ndcg:0.45593
# [2]	validation_0-ndcg:0.46603
# [3]	validation_0-ndcg:0.46361
# [4]	validation_0-ndcg:0.46412
# [5]	validation_0-ndcg:0.46566
# [6]	validation_0-ndcg:0.46447
# [7]	validation_0-ndcg:0.46525
# [8]	validation_0-ndcg:0.46380
# [9]	validation_0-ndcg:0.46448
# [10]	validation_0-ndcg:0.46440
# [11]	validation_0-ndcg:0.46464
# XGBRanker(base_score=None, booster='gbtree', callbacks=None,
#           colsample_bylevel=None, colsample_bynode=None, colsample_bytree=0.9,
#           early_stopping_rounds=None, enable_categorical=False,
#           eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#           grow_policy=None, importance_type=None, interaction_constraints=None,
#           learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#           max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#           max_leaves=None, min_child_weight=None, missing=nan,
#           monotone_constraints=None, n_estimators=100, n_jobs=None,
#           num_parallel_tree=None, objective='rank:ndcg', predictor=None, ...)

# %% [markdown]
# # Train XGBRanker only for the selected optimized parameters

# %%
params = {
    'objective' : ['rank:ndcg'],
    'booster' : ['gbtree'],
    'tree_method' : ['auto', 'exact', 'approx', 'hist', 'gpu_hist'],
    'random_state' : [42],
    'learning_rate' : [0.001, 0.01, 0.1],
    'colsample_bytree' : [0.3,0.5,0.7,0.9],
    'max_depth' : range(5,15),
    'n_estimators' : [100, 200, 500, 1000],
    'subsample' : [0.4, 0.5, 0.7, 0.8],
    'reg_alpha': [1e-5, 1e-2, 0.1, 1, 100],
    'reg_lambda': [1e-5, 1e-2, 0.1, 1, 100]
}

# These variables will return the 'optimized' hyper-parameters
best_params = None
best_score = -1

# We will store all parameter values in a list: 
param_vals = [val for val in params.values()]
# We will loop through all possible combinations from above / (*paramvals) returns all possible combinations of parameters
# then we return a list of fictionaries, where each one bind the initial keys from the params dictionary + each combination of parameters
param_combinations = [dict(zip(params.keys(), prod)) for prod in product(*param_vals)]

for param_dict in param_combinations:
    # Instantiate the model, using each set of hyperparameters
    model  = xgb.XGBRanker(**param_dict)
    # fit each model with unique combination of hyperparameters
    model.fit(X_train, y_train, group=group_train,
           eval_set=[(X_test, y_test)], eval_group=[group_test],
             eval_metric='ndcg', early_stopping_rounds = 10, verbose=True)
    
    # This would return the highest accuracy rank, based on the ndcg
    result = model.evals_result()

    # If the score is higher than the current best score, update best score and best parameters
    if result['validation_0']['ndcg'][-1] > best_score:
        best_score = result['validation_0']['ndcg'][-1]
        best_params = param_dict
# Out:
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41813
# [3]	validation_0-ndcg:0.41428
# [4]	validation_0-ndcg:0.41335
# [5]	validation_0-ndcg:0.41345
# [6]	validation_0-ndcg:0.41732
# [7]	validation_0-ndcg:0.41601
# [8]	validation_0-ndcg:0.42068
# [9]	validation_0-ndcg:0.43688
# [10]	validation_0-ndcg:0.43410
# [11]	validation_0-ndcg:0.43263
# [12]	validation_0-ndcg:0.44046
# [13]	validation_0-ndcg:0.44185
# [14]	validation_0-ndcg:0.43877
# [15]	validation_0-ndcg:0.44505
# [16]	validation_0-ndcg:0.44389
# [17]	validation_0-ndcg:0.44124
# [18]	validation_0-ndcg:0.44780
# [19]	validation_0-ndcg:0.44672
# [20]	validation_0-ndcg:0.45120
# [21]	validation_0-ndcg:0.44923
# [22]	validation_0-ndcg:0.44985
# [23]	validation_0-ndcg:0.44936
# [24]	validation_0-ndcg:0.44889
# [25]	validation_0-ndcg:0.45263
# [26]	validation_0-ndcg:0.45095
# [27]	validation_0-ndcg:0.45045
# [28]	validation_0-ndcg:0.44999
# [29]	validation_0-ndcg:0.45335
# [30]	validation_0-ndcg:0.45200
# [31]	validation_0-ndcg:0.45121
# [32]	validation_0-ndcg:0.45029
# [33]	validation_0-ndcg:0.44900
# [34]	validation_0-ndcg:0.44923
# [35]	validation_0-ndcg:0.44879
# [36]	validation_0-ndcg:0.45068
# [37]	validation_0-ndcg:0.44942
# [38]	validation_0-ndcg:0.45096
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41813
# [3]	validation_0-ndcg:0.41428
# [4]	validation_0-ndcg:0.41335
# [5]	validation_0-ndcg:0.41345
# [6]	validation_0-ndcg:0.41732
# [7]	validation_0-ndcg:0.41601
# [8]	validation_0-ndcg:0.42068
# [9]	validation_0-ndcg:0.43690
# [10]	validation_0-ndcg:0.43419
# [11]	validation_0-ndcg:0.43260
# [12]	validation_0-ndcg:0.44043
# [13]	validation_0-ndcg:0.44183
# [14]	validation_0-ndcg:0.43882
# [15]	validation_0-ndcg:0.44518
# [16]	validation_0-ndcg:0.44396
# [17]	validation_0-ndcg:0.44116
# [18]	validation_0-ndcg:0.44789
# [19]	validation_0-ndcg:0.44686
# [20]	validation_0-ndcg:0.45123
# [21]	validation_0-ndcg:0.44928
# [22]	validation_0-ndcg:0.44995
# [23]	validation_0-ndcg:0.44943
# [24]	validation_0-ndcg:0.44893
# [25]	validation_0-ndcg:0.45276
# [26]	validation_0-ndcg:0.45108
# [27]	validation_0-ndcg:0.45038
# [28]	validation_0-ndcg:0.45004
# [29]	validation_0-ndcg:0.45342
# [30]	validation_0-ndcg:0.45211
# [31]	validation_0-ndcg:0.45121
# [32]	validation_0-ndcg:0.45031
# [33]	validation_0-ndcg:0.44915
# [34]	validation_0-ndcg:0.44932
# [35]	validation_0-ndcg:0.44889
# [36]	validation_0-ndcg:0.45073
# [37]	validation_0-ndcg:0.44966
# [38]	validation_0-ndcg:0.45123
# [39]	validation_0-ndcg:0.45119
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41813
# [3]	validation_0-ndcg:0.41428
# [4]	validation_0-ndcg:0.41335
# [5]	validation_0-ndcg:0.41345
# [6]	validation_0-ndcg:0.41732
# [7]	validation_0-ndcg:0.41601
# [8]	validation_0-ndcg:0.42067
# [9]	validation_0-ndcg:0.43689
# [10]	validation_0-ndcg:0.43410
# [11]	validation_0-ndcg:0.43263
# [12]	validation_0-ndcg:0.44047
# [13]	validation_0-ndcg:0.44185
# [14]	validation_0-ndcg:0.43882
# [15]	validation_0-ndcg:0.44518
# [16]	validation_0-ndcg:0.44394
# [17]	validation_0-ndcg:0.44118
# [18]	validation_0-ndcg:0.44790
# [19]	validation_0-ndcg:0.44685
# [20]	validation_0-ndcg:0.45121
# [21]	validation_0-ndcg:0.44920
# [22]	validation_0-ndcg:0.45000
# [23]	validation_0-ndcg:0.44946
# [24]	validation_0-ndcg:0.44897
# [25]	validation_0-ndcg:0.45281
# [26]	validation_0-ndcg:0.45109
# [27]	validation_0-ndcg:0.45040
# [28]	validation_0-ndcg:0.45004
# [29]	validation_0-ndcg:0.45339
# [30]	validation_0-ndcg:0.45209
# [31]	validation_0-ndcg:0.45115
# [32]	validation_0-ndcg:0.45025
# [33]	validation_0-ndcg:0.44908
# [34]	validation_0-ndcg:0.44938
# [35]	validation_0-ndcg:0.44885
# [36]	validation_0-ndcg:0.45066
# [37]	validation_0-ndcg:0.44955
# [38]	validation_0-ndcg:0.45105
# [39]	validation_0-ndcg:0.45100
# [0]	validation_0-ndcg:0.38739
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41817
# [3]	validation_0-ndcg:0.41440
# [4]	validation_0-ndcg:0.41354
# [5]	validation_0-ndcg:0.41355
# [6]	validation_0-ndcg:0.41707
# [7]	validation_0-ndcg:0.41599
# [8]	validation_0-ndcg:0.42081
# [9]	validation_0-ndcg:0.43689
# [10]	validation_0-ndcg:0.43413
# [11]	validation_0-ndcg:0.43277
# [12]	validation_0-ndcg:0.44032
# [13]	validation_0-ndcg:0.44183
# [14]	validation_0-ndcg:0.43878
# [15]	validation_0-ndcg:0.44524
# [16]	validation_0-ndcg:0.44389
# [17]	validation_0-ndcg:0.44114
# [18]	validation_0-ndcg:0.44800
# [19]	validation_0-ndcg:0.44702
# [20]	validation_0-ndcg:0.45122
# [21]	validation_0-ndcg:0.44925
# [22]	validation_0-ndcg:0.44983
# [23]	validation_0-ndcg:0.44940
# [24]	validation_0-ndcg:0.44893
# [25]	validation_0-ndcg:0.45259
# [26]	validation_0-ndcg:0.45096
# [27]	validation_0-ndcg:0.45040
# [28]	validation_0-ndcg:0.44995
# [29]	validation_0-ndcg:0.45332
# [30]	validation_0-ndcg:0.45205
# [31]	validation_0-ndcg:0.45116
# [32]	validation_0-ndcg:0.45026
# [33]	validation_0-ndcg:0.44888
# [34]	validation_0-ndcg:0.44923
# [35]	validation_0-ndcg:0.44873
# [36]	validation_0-ndcg:0.45063
# [37]	validation_0-ndcg:0.44958
# [38]	validation_0-ndcg:0.45105
# [39]	validation_0-ndcg:0.45107
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40406
# [2]	validation_0-ndcg:0.41650
# [3]	validation_0-ndcg:0.41311
# [4]	validation_0-ndcg:0.41267
# [5]	validation_0-ndcg:0.41285
# [6]	validation_0-ndcg:0.41697
# [7]	validation_0-ndcg:0.41603
# [8]	validation_0-ndcg:0.42022
# [9]	validation_0-ndcg:0.43684
# [10]	validation_0-ndcg:0.43420
# [11]	validation_0-ndcg:0.43300
# [12]	validation_0-ndcg:0.44078
# [13]	validation_0-ndcg:0.44166
# [14]	validation_0-ndcg:0.43884
# [15]	validation_0-ndcg:0.44554
# [16]	validation_0-ndcg:0.44414
# [17]	validation_0-ndcg:0.44159
# [18]	validation_0-ndcg:0.44811
# [19]	validation_0-ndcg:0.44714
# [20]	validation_0-ndcg:0.45141
# [21]	validation_0-ndcg:0.44936
# [22]	validation_0-ndcg:0.45033
# [23]	validation_0-ndcg:0.44958
# [24]	validation_0-ndcg:0.44927
# [25]	validation_0-ndcg:0.45279
# [26]	validation_0-ndcg:0.45117
# [27]	validation_0-ndcg:0.45057
# [28]	validation_0-ndcg:0.45004
# [29]	validation_0-ndcg:0.45371
# [30]	validation_0-ndcg:0.45246
# [31]	validation_0-ndcg:0.45165
# [32]	validation_0-ndcg:0.45052
# [33]	validation_0-ndcg:0.44943
# [34]	validation_0-ndcg:0.44961
# [35]	validation_0-ndcg:0.44916
# [36]	validation_0-ndcg:0.45092
# [37]	validation_0-ndcg:0.44991
# [38]	validation_0-ndcg:0.45142
# [39]	validation_0-ndcg:0.45147
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41813
# [3]	validation_0-ndcg:0.41428
# [4]	validation_0-ndcg:0.41335
# [5]	validation_0-ndcg:0.41345
# [6]	validation_0-ndcg:0.41732
# [7]	validation_0-ndcg:0.41600
# [8]	validation_0-ndcg:0.42068
# [9]	validation_0-ndcg:0.43690
# [10]	validation_0-ndcg:0.43420
# [11]	validation_0-ndcg:0.43265
# [12]	validation_0-ndcg:0.44047
# [13]	validation_0-ndcg:0.44184
# [14]	validation_0-ndcg:0.43887
# [15]	validation_0-ndcg:0.44523
# [16]	validation_0-ndcg:0.44381
# [17]	validation_0-ndcg:0.44112
# [18]	validation_0-ndcg:0.44780
# [19]	validation_0-ndcg:0.44685
# [20]	validation_0-ndcg:0.45114
# [21]	validation_0-ndcg:0.44914
# [22]	validation_0-ndcg:0.44985
# [23]	validation_0-ndcg:0.44940
# [24]	validation_0-ndcg:0.44907
# [25]	validation_0-ndcg:0.45278
# [26]	validation_0-ndcg:0.45111
# [27]	validation_0-ndcg:0.45031
# [28]	validation_0-ndcg:0.44984
# [29]	validation_0-ndcg:0.45343
# [30]	validation_0-ndcg:0.45207
# [31]	validation_0-ndcg:0.45109
# [32]	validation_0-ndcg:0.45020
# [33]	validation_0-ndcg:0.44896
# [34]	validation_0-ndcg:0.44921
# [35]	validation_0-ndcg:0.44877
# [36]	validation_0-ndcg:0.45053
# [37]	validation_0-ndcg:0.44944
# [38]	validation_0-ndcg:0.45098
# [39]	validation_0-ndcg:0.45094
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41813
# [3]	validation_0-ndcg:0.41428
# [4]	validation_0-ndcg:0.41335
# [5]	validation_0-ndcg:0.41345
# [6]	validation_0-ndcg:0.41732
# [7]	validation_0-ndcg:0.41601
# [8]	validation_0-ndcg:0.42068
# [9]	validation_0-ndcg:0.43690
# [10]	validation_0-ndcg:0.43420
# [11]	validation_0-ndcg:0.43260
# [12]	validation_0-ndcg:0.44043
# [13]	validation_0-ndcg:0.44182
# [14]	validation_0-ndcg:0.43882
# [15]	validation_0-ndcg:0.44518
# [16]	validation_0-ndcg:0.44396
# [17]	validation_0-ndcg:0.44119
# [18]	validation_0-ndcg:0.44789
# [19]	validation_0-ndcg:0.44686
# [20]	validation_0-ndcg:0.45121
# [21]	validation_0-ndcg:0.44927
# [22]	validation_0-ndcg:0.44994
# [23]	validation_0-ndcg:0.44940
# [24]	validation_0-ndcg:0.44891
# [25]	validation_0-ndcg:0.45277
# [26]	validation_0-ndcg:0.45108
# [27]	validation_0-ndcg:0.45040
# [28]	validation_0-ndcg:0.45005
# [29]	validation_0-ndcg:0.45342
# [30]	validation_0-ndcg:0.45204
# [31]	validation_0-ndcg:0.45114
# [32]	validation_0-ndcg:0.45028
# [33]	validation_0-ndcg:0.44909
# [34]	validation_0-ndcg:0.44933
# [35]	validation_0-ndcg:0.44883
# [36]	validation_0-ndcg:0.45063
# [37]	validation_0-ndcg:0.44959
# [38]	validation_0-ndcg:0.45104
# [39]	validation_0-ndcg:0.45098
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41813
# [3]	validation_0-ndcg:0.41428
# [4]	validation_0-ndcg:0.41335
# [5]	validation_0-ndcg:0.41345
# [6]	validation_0-ndcg:0.41732
# [7]	validation_0-ndcg:0.41601
# [8]	validation_0-ndcg:0.42068
# [9]	validation_0-ndcg:0.43688
# [10]	validation_0-ndcg:0.43411
# [11]	validation_0-ndcg:0.43269
# [12]	validation_0-ndcg:0.44047
# [13]	validation_0-ndcg:0.44183
# [14]	validation_0-ndcg:0.43879
# [15]	validation_0-ndcg:0.44521
# [16]	validation_0-ndcg:0.44392
# [17]	validation_0-ndcg:0.44125
# [18]	validation_0-ndcg:0.44780
# [19]	validation_0-ndcg:0.44679
# [20]	validation_0-ndcg:0.45118
# [21]	validation_0-ndcg:0.44913
# [22]	validation_0-ndcg:0.44989
# [23]	validation_0-ndcg:0.44945
# [24]	validation_0-ndcg:0.44894
# [25]	validation_0-ndcg:0.45252
# [26]	validation_0-ndcg:0.45085
# [27]	validation_0-ndcg:0.45029
# [28]	validation_0-ndcg:0.44976
# [29]	validation_0-ndcg:0.45325
# [30]	validation_0-ndcg:0.45196
# [31]	validation_0-ndcg:0.45106
# [32]	validation_0-ndcg:0.45017
# [33]	validation_0-ndcg:0.44891
# [34]	validation_0-ndcg:0.44912
# [35]	validation_0-ndcg:0.44873
# [36]	validation_0-ndcg:0.45058
# [37]	validation_0-ndcg:0.44947
# [38]	validation_0-ndcg:0.45092
# [39]	validation_0-ndcg:0.45091
# [0]	validation_0-ndcg:0.38739
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41817
# [3]	validation_0-ndcg:0.41440
# [4]	validation_0-ndcg:0.41354
# [5]	validation_0-ndcg:0.41355
# [6]	validation_0-ndcg:0.41706
# [7]	validation_0-ndcg:0.41599
# [8]	validation_0-ndcg:0.42082
# [9]	validation_0-ndcg:0.43689
# [10]	validation_0-ndcg:0.43412
# [11]	validation_0-ndcg:0.43275
# [12]	validation_0-ndcg:0.44031
# [13]	validation_0-ndcg:0.44182
# [14]	validation_0-ndcg:0.43878
# [15]	validation_0-ndcg:0.44523
# [16]	validation_0-ndcg:0.44387
# [17]	validation_0-ndcg:0.44114
# [18]	validation_0-ndcg:0.44800
# [19]	validation_0-ndcg:0.44700
# [20]	validation_0-ndcg:0.45121
# [21]	validation_0-ndcg:0.44924
# [22]	validation_0-ndcg:0.44983
# [23]	validation_0-ndcg:0.44940
# [24]	validation_0-ndcg:0.44892
# [25]	validation_0-ndcg:0.45260
# [26]	validation_0-ndcg:0.45097
# [27]	validation_0-ndcg:0.45038
# [28]	validation_0-ndcg:0.44994
# [29]	validation_0-ndcg:0.45329
# [30]	validation_0-ndcg:0.45206
# [31]	validation_0-ndcg:0.45116
# [32]	validation_0-ndcg:0.45028
# [33]	validation_0-ndcg:0.44892
# [34]	validation_0-ndcg:0.44923
# [35]	validation_0-ndcg:0.44877
# [36]	validation_0-ndcg:0.45061
# [37]	validation_0-ndcg:0.44950
# [38]	validation_0-ndcg:0.45107
# [39]	validation_0-ndcg:0.45108
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40406
# [2]	validation_0-ndcg:0.41650
# [3]	validation_0-ndcg:0.41312
# [4]	validation_0-ndcg:0.41266
# [5]	validation_0-ndcg:0.41284
# [6]	validation_0-ndcg:0.41697
# [7]	validation_0-ndcg:0.41603
# [8]	validation_0-ndcg:0.42023
# [9]	validation_0-ndcg:0.43685
# [10]	validation_0-ndcg:0.43420
# [11]	validation_0-ndcg:0.43299
# [12]	validation_0-ndcg:0.44080
# [13]	validation_0-ndcg:0.44167
# [14]	validation_0-ndcg:0.43885
# [15]	validation_0-ndcg:0.44557
# [16]	validation_0-ndcg:0.44429
# [17]	validation_0-ndcg:0.44168
# [18]	validation_0-ndcg:0.44813
# [19]	validation_0-ndcg:0.44712
# [20]	validation_0-ndcg:0.45137
# [21]	validation_0-ndcg:0.44944
# [22]	validation_0-ndcg:0.45027
# [23]	validation_0-ndcg:0.44956
# [24]	validation_0-ndcg:0.44913
# [25]	validation_0-ndcg:0.45279
# [26]	validation_0-ndcg:0.45125
# [27]	validation_0-ndcg:0.45056
# [28]	validation_0-ndcg:0.45003
# [29]	validation_0-ndcg:0.45373
# [30]	validation_0-ndcg:0.45242
# [31]	validation_0-ndcg:0.45163
# [32]	validation_0-ndcg:0.45060
# [33]	validation_0-ndcg:0.44936
# [34]	validation_0-ndcg:0.44956
# [35]	validation_0-ndcg:0.44905
# [36]	validation_0-ndcg:0.45088
# [37]	validation_0-ndcg:0.44981
# [38]	validation_0-ndcg:0.45134
# [39]	validation_0-ndcg:0.45138
# [0]	validation_0-ndcg:0.38733
# [1]	validation_0-ndcg:0.40442
# [2]	validation_0-ndcg:0.41809
# [3]	validation_0-ndcg:0.41418
# [4]	validation_0-ndcg:0.41342
# [5]	validation_0-ndcg:0.41365
# [6]	validation_0-ndcg:0.41716
# [7]	validation_0-ndcg:0.41606
# [8]	validation_0-ndcg:0.42046
# [9]	validation_0-ndcg:0.43674
# [10]	validation_0-ndcg:0.43402
# [11]	validation_0-ndcg:0.43268
# [12]	validation_0-ndcg:0.44045
# [13]	validation_0-ndcg:0.44149
# [14]	validation_0-ndcg:0.43855
# [15]	validation_0-ndcg:0.44515
# [16]	validation_0-ndcg:0.44381
# [17]	validation_0-ndcg:0.44100
# [18]	validation_0-ndcg:0.44773
# [19]	validation_0-ndcg:0.44655
# [20]	validation_0-ndcg:0.45104
# [21]	validation_0-ndcg:0.44889
# [22]	validation_0-ndcg:0.44975
# [23]	validation_0-ndcg:0.44925
# [24]	validation_0-ndcg:0.44863
# [25]	validation_0-ndcg:0.45236
# [26]	validation_0-ndcg:0.45079
# [27]	validation_0-ndcg:0.45005
# [28]	validation_0-ndcg:0.44969
# [29]	validation_0-ndcg:0.45312
# [30]	validation_0-ndcg:0.45187
# [31]	validation_0-ndcg:0.45100
# [32]	validation_0-ndcg:0.45006
# [33]	validation_0-ndcg:0.44893
# [34]	validation_0-ndcg:0.44909
# [35]	validation_0-ndcg:0.44851
# [36]	validation_0-ndcg:0.45037
# [37]	validation_0-ndcg:0.44946
# [38]	validation_0-ndcg:0.45090
# [39]	validation_0-ndcg:0.45092
# [0]	validation_0-ndcg:0.38733
# [1]	validation_0-ndcg:0.40442
# [2]	validation_0-ndcg:0.41809
# [3]	validation_0-ndcg:0.41418
# [4]	validation_0-ndcg:0.41342
# [5]	validation_0-ndcg:0.41365
# [6]	validation_0-ndcg:0.41716
# [7]	validation_0-ndcg:0.41606
# [8]	validation_0-ndcg:0.42046
# [9]	validation_0-ndcg:0.43673
# [10]	validation_0-ndcg:0.43402
# [11]	validation_0-ndcg:0.43267
# [12]	validation_0-ndcg:0.44045
# [13]	validation_0-ndcg:0.44148
# [14]	validation_0-ndcg:0.43855
# [15]	validation_0-ndcg:0.44514
# [16]	validation_0-ndcg:0.44380
# [17]	validation_0-ndcg:0.44100
# [18]	validation_0-ndcg:0.44773
# [19]	validation_0-ndcg:0.44655
# [20]	validation_0-ndcg:0.45104
# [21]	validation_0-ndcg:0.44890
# [22]	validation_0-ndcg:0.44976
# [23]	validation_0-ndcg:0.44925
# [24]	validation_0-ndcg:0.44864
# [25]	validation_0-ndcg:0.45236
# [26]	validation_0-ndcg:0.45079
# [27]	validation_0-ndcg:0.45005
# [28]	validation_0-ndcg:0.44969
# [29]	validation_0-ndcg:0.45311
# [30]	validation_0-ndcg:0.45186
# [31]	validation_0-ndcg:0.45100
# [32]	validation_0-ndcg:0.45006
# [33]	validation_0-ndcg:0.44893
# [34]	validation_0-ndcg:0.44909
# [35]	validation_0-ndcg:0.44850
# [36]	validation_0-ndcg:0.45036
# [37]	validation_0-ndcg:0.44946
# [38]	validation_0-ndcg:0.45089
# [39]	validation_0-ndcg:0.45092
# [0]	validation_0-ndcg:0.38733
# [1]	validation_0-ndcg:0.40442
# [2]	validation_0-ndcg:0.41809
# [3]	validation_0-ndcg:0.41418
# [4]	validation_0-ndcg:0.41342
# [5]	validation_0-ndcg:0.41365
# [6]	validation_0-ndcg:0.41717
# [7]	validation_0-ndcg:0.41606
# [8]	validation_0-ndcg:0.42046
# [9]	validation_0-ndcg:0.43674
# [10]	validation_0-ndcg:0.43403
# [11]	validation_0-ndcg:0.43266
# [12]	validation_0-ndcg:0.44043
# [13]	validation_0-ndcg:0.44153
# [14]	validation_0-ndcg:0.43858
# [15]	validation_0-ndcg:0.44513
# [16]	validation_0-ndcg:0.44381
# [17]	validation_0-ndcg:0.44099
# [18]	validation_0-ndcg:0.44774
# [19]	validation_0-ndcg:0.44656
# [20]	validation_0-ndcg:0.45103
# [21]	validation_0-ndcg:0.44888
# [22]	validation_0-ndcg:0.44978
# [23]	validation_0-ndcg:0.44918
# [24]	validation_0-ndcg:0.44865
# [25]	validation_0-ndcg:0.45236
# [26]	validation_0-ndcg:0.45078
# [27]	validation_0-ndcg:0.45004
# [28]	validation_0-ndcg:0.44954
# [29]	validation_0-ndcg:0.45310
# [30]	validation_0-ndcg:0.45180
# [31]	validation_0-ndcg:0.45098
# [32]	validation_0-ndcg:0.45007
# [33]	validation_0-ndcg:0.44879
# [34]	validation_0-ndcg:0.44905
# [35]	validation_0-ndcg:0.44847
# [36]	validation_0-ndcg:0.45039
# [37]	validation_0-ndcg:0.44946
# [38]	validation_0-ndcg:0.45081
# [39]	validation_0-ndcg:0.45079
# [0]	validation_0-ndcg:0.38739
# [1]	validation_0-ndcg:0.40444
# [2]	validation_0-ndcg:0.41819
# [3]	validation_0-ndcg:0.41440
# [4]	validation_0-ndcg:0.41353
# [5]	validation_0-ndcg:0.41356
# [6]	validation_0-ndcg:0.41736
# [7]	validation_0-ndcg:0.41609
# [8]	validation_0-ndcg:0.42060
# [9]	validation_0-ndcg:0.43687
# [10]	validation_0-ndcg:0.43409
# [11]	validation_0-ndcg:0.43267
# [12]	validation_0-ndcg:0.44048
# [13]	validation_0-ndcg:0.44171
# [14]	validation_0-ndcg:0.43865
# [15]	validation_0-ndcg:0.44506
# [16]	validation_0-ndcg:0.44379
# [17]	validation_0-ndcg:0.44103
# [18]	validation_0-ndcg:0.44788
# [19]	validation_0-ndcg:0.44679
# [20]	validation_0-ndcg:0.45115
# [21]	validation_0-ndcg:0.44919
# [22]	validation_0-ndcg:0.44996
# [23]	validation_0-ndcg:0.44943
# [24]	validation_0-ndcg:0.44889
# [25]	validation_0-ndcg:0.45258
# [26]	validation_0-ndcg:0.45093
# [27]	validation_0-ndcg:0.45035
# [28]	validation_0-ndcg:0.44991
# [29]	validation_0-ndcg:0.45332
# [30]	validation_0-ndcg:0.45201
# [31]	validation_0-ndcg:0.45109
# [32]	validation_0-ndcg:0.45026
# [33]	validation_0-ndcg:0.44905
# [34]	validation_0-ndcg:0.44928
# [35]	validation_0-ndcg:0.44878
# [36]	validation_0-ndcg:0.45055
# [37]	validation_0-ndcg:0.44939
# [38]	validation_0-ndcg:0.45087
# [39]	validation_0-ndcg:0.45090
# [0]	validation_0-ndcg:0.38732
# [1]	validation_0-ndcg:0.40404
# [2]	validation_0-ndcg:0.41649
# [3]	validation_0-ndcg:0.41311
# [4]	validation_0-ndcg:0.41265
# [5]	validation_0-ndcg:0.41287
# [6]	validation_0-ndcg:0.41697
# [7]	validation_0-ndcg:0.41604
# [8]	validation_0-ndcg:0.42022
# [9]	validation_0-ndcg:0.43685
# [10]	validation_0-ndcg:0.43420
# [11]	validation_0-ndcg:0.43299
# [12]	validation_0-ndcg:0.44080
# [13]	validation_0-ndcg:0.44168
# [14]	validation_0-ndcg:0.43885
# [15]	validation_0-ndcg:0.44558
# [16]	validation_0-ndcg:0.44428
# [17]	validation_0-ndcg:0.44168
# [18]	validation_0-ndcg:0.44816
# [19]	validation_0-ndcg:0.44715
# [20]	validation_0-ndcg:0.45138
# [21]	validation_0-ndcg:0.44942
# [22]	validation_0-ndcg:0.45017
# [23]	validation_0-ndcg:0.44985
# [24]	validation_0-ndcg:0.44934
# [25]	validation_0-ndcg:0.45306
# [26]	validation_0-ndcg:0.45146
# [27]	validation_0-ndcg:0.45072
# [28]	validation_0-ndcg:0.45018
# [29]	validation_0-ndcg:0.45378
# [30]	validation_0-ndcg:0.45248
# [31]	validation_0-ndcg:0.45156
# [32]	validation_0-ndcg:0.45062
# [33]	validation_0-ndcg:0.44934
# [34]	validation_0-ndcg:0.44960
# [35]	validation_0-ndcg:0.44917
# [36]	validation_0-ndcg:0.45096
# [37]	validation_0-ndcg:0.44999
# [38]	validation_0-ndcg:0.45136
# [39]	validation_0-ndcg:0.45141
# [0]	validation_0-ndcg:0.38745
# [1]	validation_0-ndcg:0.40443
# [2]	validation_0-ndcg:0.41797
# [3]	validation_0-ndcg:0.41425
# [4]	validation_0-ndcg:0.41368
# [5]	validation_0-ndcg:0.41376
# [6]	validation_0-ndcg:0.41714
# [7]	validation_0-ndcg:0.41591
# [8]	validation_0-ndcg:0.42041
# [9]	validation_0-ndcg:0.43674
# [10]	validation_0-ndcg:0.43400
# [11]	validation_0-ndcg:0.43274
# [12]	validation_0-ndcg:0.44027
# [13]	validation_0-ndcg:0.44137
# [14]	validation_0-ndcg:0.43828
# [15]	validation_0-ndcg:0.44481
# [16]	validation_0-ndcg:0.44362
# [17]	validation_0-ndcg:0.44083
# [18]	validation_0-ndcg:0.44765
# [19]	validation_0-ndcg:0.44653
# [20]	validation_0-ndcg:0.45084
# [21]	validation_0-ndcg:0.44882
# [22]	validation_0-ndcg:0.44946
# [23]	validation_0-ndcg:0.44903
# [24]	validation_0-ndcg:0.44850
# [25]	validation_0-ndcg:0.45211
# [26]	validation_0-ndcg:0.45055
# [27]	validation_0-ndcg:0.44995
# [28]	validation_0-ndcg:0.44946
# [29]	validation_0-ndcg:0.45307
# [30]	validation_0-ndcg:0.45184
# [31]	validation_0-ndcg:0.45095
# [32]	validation_0-ndcg:0.44995
# [33]	validation_0-ndcg:0.44868
# [34]	validation_0-ndcg:0.44906
# [35]	validation_0-ndcg:0.44851
# [36]	validation_0-ndcg:0.45040
# [37]	validation_0-ndcg:0.44928
# [38]	validation_0-ndcg:0.45092
# [39]	validation_0-ndcg:0.45091
# [0]	validation_0-ndcg:0.38745
# [1]	validation_0-ndcg:0.40443
# [2]	validation_0-ndcg:0.41797
# [3]	validation_0-ndcg:0.41425
# [4]	validation_0-ndcg:0.41368
# [5]	validation_0-ndcg:0.41376
# [6]	validation_0-ndcg:0.41714
# [7]	validation_0-ndcg:0.41591
# [8]	validation_0-ndcg:0.42041
# [9]	validation_0-ndcg:0.43674
# [10]	validation_0-ndcg:0.43400
# [11]	validation_0-ndcg:0.43274
# [12]	validation_0-ndcg:0.44031
# [13]	validation_0-ndcg:0.44140
# [14]	validation_0-ndcg:0.43838
# [15]	validation_0-ndcg:0.44485
# [16]	validation_0-ndcg:0.44365
# [17]	validation_0-ndcg:0.44088
# [18]	validation_0-ndcg:0.44766
# [19]	validation_0-ndcg:0.44654
# [20]	validation_0-ndcg:0.45090
# [21]	validation_0-ndcg:0.44882
# [22]	validation_0-ndcg:0.44944
# [23]	validation_0-ndcg:0.44904
# [24]	validation_0-ndcg:0.44858
# [25]	validation_0-ndcg:0.45228
# [26]	validation_0-ndcg:0.45067
# [27]	validation_0-ndcg:0.45003
# [28]	validation_0-ndcg:0.44945
# [29]	validation_0-ndcg:0.45300
# [30]	validation_0-ndcg:0.45182
# [31]	validation_0-ndcg:0.45091
# [32]	validation_0-ndcg:0.44993
# [33]	validation_0-ndcg:0.44865
# [34]	validation_0-ndcg:0.44897
# [35]	validation_0-ndcg:0.44845
# [36]	validation_0-ndcg:0.45045
# [37]	validation_0-ndcg:0.44920
# [38]	validation_0-ndcg:0.45084
# [39]	validation_0-ndcg:0.45081
# [0]	validation_0-ndcg:0.38745
# [1]	validation_0-ndcg:0.40443
# [2]	validation_0-ndcg:0.41797
# [3]	validation_0-ndcg:0.41424
# [4]	validation_0-ndcg:0.41369
# [5]	validation_0-ndcg:0.41374
# [6]	validation_0-ndcg:0.41713
# [7]	validation_0-ndcg:0.41589
# [8]	validation_0-ndcg:0.42039
# [9]	validation_0-ndcg:0.43668
# [10]	validation_0-ndcg:0.43394
# [11]	validation_0-ndcg:0.43252
# [12]	validation_0-ndcg:0.44028
# [13]	validation_0-ndcg:0.44133
# [14]	validation_0-ndcg:0.43834
# [15]	validation_0-ndcg:0.44467
# [16]	validation_0-ndcg:0.44350
# [17]	validation_0-ndcg:0.44076
# [18]	validation_0-ndcg:0.44759
# [19]	validation_0-ndcg:0.44665
# [20]	validation_0-ndcg:0.45097
# [21]	validation_0-ndcg:0.44886
# [22]	validation_0-ndcg:0.44950
# [23]	validation_0-ndcg:0.44902
# [24]	validation_0-ndcg:0.44869
# [25]	validation_0-ndcg:0.45243
# [26]	validation_0-ndcg:0.45079
# [27]	validation_0-ndcg:0.45022
# [28]	validation_0-ndcg:0.44954
# [29]	validation_0-ndcg:0.45296
# [30]	validation_0-ndcg:0.45169
# [31]	validation_0-ndcg:0.45076
# [32]	validation_0-ndcg:0.44986
# [33]	validation_0-ndcg:0.44874
# [34]	validation_0-ndcg:0.44898
# [35]	validation_0-ndcg:0.44846
# [36]	validation_0-ndcg:0.45030
# [37]	validation_0-ndcg:0.44928
# [38]	validation_0-ndcg:0.45076
# [0]	validation_0-ndcg:0.38742
# [1]	validation_0-ndcg:0.40443
# [2]	validation_0-ndcg:0.41797
# [3]	validation_0-ndcg:0.41427
# [4]	validation_0-ndcg:0.41351
# [5]	validation_0-ndcg:0.41351
# [6]	validation_0-ndcg:0.41713
# [7]	validation_0-ndcg:0.41604
# [8]	validation_0-ndcg:0.42092
# [9]	validation_0-ndcg:0.43686
# [10]	validation_0-ndcg:0.43401
# [11]	validation_0-ndcg:0.43273
# [12]	validation_0-ndcg:0.44030
# [13]	validation_0-ndcg:0.44162
# [14]	validation_0-ndcg:0.43862
# [15]	validation_0-ndcg:0.44507
# [16]	validation_0-ndcg:0.44374
# [17]	validation_0-ndcg:0.44117
# [18]	validation_0-ndcg:0.44782
# [19]	validation_0-ndcg:0.44684
# [20]	validation_0-ndcg:0.45133
# [21]	validation_0-ndcg:0.44921
# [22]	validation_0-ndcg:0.44973
# [23]	validation_0-ndcg:0.44918
# [24]	validation_0-ndcg:0.44893
# [25]	validation_0-ndcg:0.45253
# [26]	validation_0-ndcg:0.45093
# [27]	validation_0-ndcg:0.45022
# [28]	validation_0-ndcg:0.44976
# [29]	validation_0-ndcg:0.45330
# [30]	validation_0-ndcg:0.45207
# [31]	validation_0-ndcg:0.45118
# [32]	validation_0-ndcg:0.45019
# [33]	validation_0-ndcg:0.44885
# [34]	validation_0-ndcg:0.44902
# [35]	validation_0-ndcg:0.44867
# [36]	validation_0-ndcg:0.45071
# [37]	validation_0-ndcg:0.44954
# [38]	validation_0-ndcg:0.45106
# [0]	validation_0-ndcg:0.38730
# [1]	validation_0-ndcg:0.40405
# [2]	validation_0-ndcg:0.41648
# [3]	validation_0-ndcg:0.41309
# [4]	validation_0-ndcg:0.41263
# [5]	validation_0-ndcg:0.41277
# [6]	validation_0-ndcg:0.41690
# [7]	validation_0-ndcg:0.41600
# [8]	validation_0-ndcg:0.42036
# [9]	validation_0-ndcg:0.43662
# [10]	validation_0-ndcg:0.43408
# [11]	validation_0-ndcg:0.43293
# [12]	validation_0-ndcg:0.44066
# [13]	validation_0-ndcg:0.44160
# [14]	validation_0-ndcg:0.43873
# [15]	validation_0-ndcg:0.44539
# [16]	validation_0-ndcg:0.44408
# [17]	validation_0-ndcg:0.44155
# [18]	validation_0-ndcg:0.44797
# [19]	validation_0-ndcg:0.44706
# [20]	validation_0-ndcg:0.45128
# [21]	validation_0-ndcg:0.44924
# [22]	validation_0-ndcg:0.45014
# [23]	validation_0-ndcg:0.44972
# [24]	validation_0-ndcg:0.44913
# [25]	validation_0-ndcg:0.45270
# [26]	validation_0-ndcg:0.45111
# [27]	validation_0-ndcg:0.45054
# [28]	validation_0-ndcg:0.45013
# [29]	validation_0-ndcg:0.45353
# [30]	validation_0-ndcg:0.45218
# [31]	validation_0-ndcg:0.45145
# [32]	validation_0-ndcg:0.45047
# [33]	validation_0-ndcg:0.44928
# [34]	validation_0-ndcg:0.44951
# [35]	validation_0-ndcg:0.44910
# [36]	validation_0-ndcg:0.45099
# [37]	validation_0-ndcg:0.44981
# [38]	validation_0-ndcg:0.45141
# [0]	validation_0-ndcg:0.38644
# [1]	validation_0-ndcg:0.40561
# [2]	validation_0-ndcg:0.41833
# [3]	validation_0-ndcg:0.41526
# [4]	validation_0-ndcg:0.41416
# [5]	validation_0-ndcg:0.41363
# [6]	validation_0-ndcg:0.41783
# [7]	validation_0-ndcg:0.41693
# [8]	validation_0-ndcg:0.42045
# [9]	validation_0-ndcg:0.43640
# [10]	validation_0-ndcg:0.43418
# [11]	validation_0-ndcg:0.43290
# [12]	validation_0-ndcg:0.44044
# [13]	validation_0-ndcg:0.44113
# [14]	validation_0-ndcg:0.43846
# [15]	validation_0-ndcg:0.44480
# [16]	validation_0-ndcg:0.44341
# [17]	validation_0-ndcg:0.44083
# [18]	validation_0-ndcg:0.44728
# [19]	validation_0-ndcg:0.44615
# [20]	validation_0-ndcg:0.45107
# [21]	validation_0-ndcg:0.44889
# [22]	validation_0-ndcg:0.44967
# [23]	validation_0-ndcg:0.44898
# [24]	validation_0-ndcg:0.44860
# [25]	validation_0-ndcg:0.45247
# [26]	validation_0-ndcg:0.45090
# [27]	validation_0-ndcg:0.45036
# [28]	validation_0-ndcg:0.44979
# [29]	validation_0-ndcg:0.45303
# [30]	validation_0-ndcg:0.45184
# [31]	validation_0-ndcg:0.45095
# [32]	validation_0-ndcg:0.44985
# [33]	validation_0-ndcg:0.44876
# [34]	validation_0-ndcg:0.44902
# [35]	validation_0-ndcg:0.44872
# [36]	validation_0-ndcg:0.45020
# [37]	validation_0-ndcg:0.44915
# [38]	validation_0-ndcg:0.45059
# [0]	validation_0-ndcg:0.38644
# [1]	validation_0-ndcg:0.40561
# [2]	validation_0-ndcg:0.41833
# [3]	validation_0-ndcg:0.41526
# [4]	validation_0-ndcg:0.41416
# [5]	validation_0-ndcg:0.41363
# [6]	validation_0-ndcg:0.41783
# [7]	validation_0-ndcg:0.41693
# [8]	validation_0-ndcg:0.42045
# [9]	validation_0-ndcg:0.43640
# [10]	validation_0-ndcg:0.43418
# [11]	validation_0-ndcg:0.43290
# [12]	validation_0-ndcg:0.44044
# [13]	validation_0-ndcg:0.44113
# [14]	validation_0-ndcg:0.43846
# [15]	validation_0-ndcg:0.44480
# [16]	validation_0-ndcg:0.44341
# [17]	validation_0-ndcg:0.44083
# [18]	validation_0-ndcg:0.44728
# [19]	validation_0-ndcg:0.44615
# [20]	validation_0-ndcg:0.45107
# [21]	validation_0-ndcg:0.44889
# [22]	validation_0-ndcg:0.44968
# [23]	validation_0-ndcg:0.44898
# [24]	validation_0-ndcg:0.44860
# [25]	validation_0-ndcg:0.45247
# [26]	validation_0-ndcg:0.45090
# [27]	validation_0-ndcg:0.45035
# [28]	validation_0-ndcg:0.44979
# [29]	validation_0-ndcg:0.45303
# [30]	validation_0-ndcg:0.45185
# [31]	validation_0-ndcg:0.45095
# [32]	validation_0-ndcg:0.44985
# [33]	validation_0-ndcg:0.44877
# [34]	validation_0-ndcg:0.44901
# [35]	validation_0-ndcg:0.44872
# [36]	validation_0-ndcg:0.45021
# [37]	validation_0-ndcg:0.44915
# [38]	validation_0-ndcg:0.45060
# [0]	validation_0-ndcg:0.38644
# [1]	validation_0-ndcg:0.40561
# [2]	validation_0-ndcg:0.41833
# [3]	validation_0-ndcg:0.41526
# [4]	validation_0-ndcg:0.41416
# [5]	validation_0-ndcg:0.41363
# [6]	validation_0-ndcg:0.41783
# [7]	validation_0-ndcg:0.41693
# [8]	validation_0-ndcg:0.42045
# [9]	validation_0-ndcg:0.43640
# [10]	validation_0-ndcg:0.43418
# [11]	validation_0-ndcg:0.43290
# [12]	validation_0-ndcg:0.44044
# [13]	validation_0-ndcg:0.44113
# [14]	validation_0-ndcg:0.43846
# [15]	validation_0-ndcg:0.44479
# [16]	validation_0-ndcg:0.44340
# [17]	validation_0-ndcg:0.44082
# [18]	validation_0-ndcg:0.44727
# [19]	validation_0-ndcg:0.44614
# [20]	validation_0-ndcg:0.45106
# [21]	validation_0-ndcg:0.44888
# [22]	validation_0-ndcg:0.44967
# [23]	validation_0-ndcg:0.44898
# [24]	validation_0-ndcg:0.44861
# [25]	validation_0-ndcg:0.45247
# [26]	validation_0-ndcg:0.45090
# [27]	validation_0-ndcg:0.45036
# [28]	validation_0-ndcg:0.44979
# [29]	validation_0-ndcg:0.45303
# [30]	validation_0-ndcg:0.45185
# [31]	validation_0-ndcg:0.45095
# [32]	validation_0-ndcg:0.44985
# [33]	validation_0-ndcg:0.44877
# [34]	validation_0-ndcg:0.44901
# [35]	validation_0-ndcg:0.44872
# [36]	validation_0-ndcg:0.45020
# [37]	validation_0-ndcg:0.44915
# [38]	validation_0-ndcg:0.45060
# [39]	validation_0-ndcg:0.45067
# [0]	validation_0-ndcg:0.38644
# [1]	validation_0-ndcg:0.40560
# [2]	validation_0-ndcg:0.41833
# [3]	validation_0-ndcg:0.41526
# [4]	validation_0-ndcg:0.41416
# [5]	validation_0-ndcg:0.41363
# [6]	validation_0-ndcg:0.41782
# [7]	validation_0-ndcg:0.41692
# [8]	validation_0-ndcg:0.42045
# [9]	validation_0-ndcg:0.43640
# [10]	validation_0-ndcg:0.43418
# [11]	validation_0-ndcg:0.43289
# [12]	validation_0-ndcg:0.44054
# [13]	validation_0-ndcg:0.44113
# [14]	validation_0-ndcg:0.43845
# [15]	validation_0-ndcg:0.44478
# [16]	validation_0-ndcg:0.44342
# [17]	validation_0-ndcg:0.44083
# [18]	validation_0-ndcg:0.44741
# [19]	validation_0-ndcg:0.44634
# [20]	validation_0-ndcg:0.45131
# [21]	validation_0-ndcg:0.44927
# [22]	validation_0-ndcg:0.44983
# [23]	validation_0-ndcg:0.44908
# [24]	validation_0-ndcg:0.44866
# [25]	validation_0-ndcg:0.45251
# [26]	validation_0-ndcg:0.45096
# [27]	validation_0-ndcg:0.45038
# [28]	validation_0-ndcg:0.44980
# [29]	validation_0-ndcg:0.45309
# [30]	validation_0-ndcg:0.45194
# [31]	validation_0-ndcg:0.45106
# [32]	validation_0-ndcg:0.44991
# [33]	validation_0-ndcg:0.44882
# [34]	validation_0-ndcg:0.44901
# [35]	validation_0-ndcg:0.44866
# [36]	validation_0-ndcg:0.45033
# [37]	validation_0-ndcg:0.44920
# [38]	validation_0-ndcg:0.45067
# [39]	validation_0-ndcg:0.45075
# [0]	validation_0-ndcg:0.38668
# [1]	validation_0-ndcg:0.40430
# [2]	validation_0-ndcg:0.41709
# [3]	validation_0-ndcg:0.41477
# [4]	validation_0-ndcg:0.41400
# [5]	validation_0-ndcg:0.41323
# [6]	validation_0-ndcg:0.41738
# [7]	validation_0-ndcg:0.41662
# [8]	validation_0-ndcg:0.42130
# [9]	validation_0-ndcg:0.43672
# [10]	validation_0-ndcg:0.43433
# [11]	validation_0-ndcg:0.43308
# [12]	validation_0-ndcg:0.44056
# [13]	validation_0-ndcg:0.44143
# [14]	validation_0-ndcg:0.43885
# [15]	validation_0-ndcg:0.44544
# [16]	validation_0-ndcg:0.44382
# [17]	validation_0-ndcg:0.44114
# [18]	validation_0-ndcg:0.44790
# [19]	validation_0-ndcg:0.44679
# [20]	validation_0-ndcg:0.45115
# [21]	validation_0-ndcg:0.44924
# [22]	validation_0-ndcg:0.44984
# [23]	validation_0-ndcg:0.44927
# [24]	validation_0-ndcg:0.44884
# [25]	validation_0-ndcg:0.45258
# [26]	validation_0-ndcg:0.45099
# [27]	validation_0-ndcg:0.45029
# [28]	validation_0-ndcg:0.44984
# [29]	validation_0-ndcg:0.45325
# [30]	validation_0-ndcg:0.45215
# [31]	validation_0-ndcg:0.45151
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 29
#      27 model  = xgb.XGBRanker(**param_dict)
#      28 # fit each model with unique combination of hyperparameters
# ---> 29 model.fit(X_train, y_train, group=group_train,
#      30        eval_set=[(X_test, y_test)], eval_group=[group_test],
#      31          eval_metric='ndcg', early_stopping_rounds = 10, verbose=True)
#      33 # This would return the highest accuracy rank, based on the ndcg
#      34 result = model.evals_result()
#
# File c:\Users\Asus\anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Asus\anaconda3\lib\site-packages\xgboost\sklearn.py:1967, in XGBRanker.fit(self, X, y, group, qid, sample_weight, base_margin, eval_set, eval_group, eval_qid, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1962 if callable(metric):
#    1963     raise ValueError(
#    1964         "Custom evaluation metric is not yet supported for XGBRanker."
#    1965     )
# -> 1967 self._Booster = train(
#    1968     params,
#    1969     train_dmatrix,
#    1970     self.get_num_boosting_rounds(),
#    1971     early_stopping_rounds=early_stopping_rounds,
#    1972     evals=evals,
#    1973     evals_result=evals_result,
#    1974     custom_metric=metric,
#    1975     verbose_eval=verbose,
#    1976     xgb_model=model,
#    1977     callbacks=callbacks,
#    1978 )
#    1980 self.objective = params["objective"]
#    1982 self._set_evaluation_result(evals_result)
#
# File c:\Users\Asus\anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Asus\anaconda3\lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File c:\Users\Asus\anaconda3\lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
print(f"Best score: {best_score}")
print(f"Best parameters: {best_params}")

# %% [markdown]
# # Now we will predict on the actual train test:

# %%
test_set = pd.read_csv('df_test_OptionB.csv')

# %%
test_set.columns
# Out:
# Index(['srch_id', 'prop_id', 'prop_starrating', 'prop_review_score',
#        'prop_brand_bool', 'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'price_usd', 'promotion_flag',
#        'srch_length_of_stay', 'srch_booking_window', 'srch_adults_count',
#        'srch_room_count', 'srch_saturday_night_bool',
#        'orig_destination_distance', 'avg_comp_rate', 'avg_comp_inv',
#        'abroad_bool', 'children_bool', 'srch_query_affinity_score_low',
#        'srch_query_affinity_score_high', 'starrating_diff_low',
#        'starrating_diff_high', 'usd_diff_low', 'usd_diff_high'],
#       dtype='object')

# %%
# Sort test set 
test_set = test_set.sort_values(by='srch_id')

# Storing the removed columns in a separate DataFrame
df_test_columns_removed = test_set[['srch_id', 'prop_id']].copy()

# # Create a new DataFrame by dropping the desired columns
test_set = test_set.drop(columns=['prop_id'], axis=1)

# %%
test_set.shape
# Out:
# (4959183, 25)

# %% [markdown]
# Since predict for XGBosst does not take an argument 'group', we need to apply the predict for each group separately:

# %%
def predict(model, df):
    """
    The function runs the prediction XGBRanker to each group of the variable
    of interest and returns a rank for this particular group

    Input:
    model: the model that we want to run on each separate category
    df: DataFrame

    Output:
    Prediction of the rank for each category
    """
    return model.predict(df.loc[:, ~df.columns.isin(['srch_id'])])

# %%
predictions = (test_set.groupby('srch_id').apply(lambda x: predict(tester, x)))

# %%
predictions
# Out:
# srch_id
# 1         [0.7237759, 0.18657094, -0.5148052, 0.12954172...
# 3         [-0.55040884, -0.88232255, -0.1006564, -0.9766...
# 6         [-0.9152836, -0.57920295, -1.3692656, -1.25394...
# 7         [0.088054456, 0.2735728, 0.25442874, 0.3738486...
# 10        [-0.38448307, -0.4979509, -0.6311435, 0.736151...
#                                 ...
# 332781    [-1.3643686, 0.105161406, 0.04398398, -0.23980...
# 332783    [-0.8326318, -0.06108358, 0.31370464, 0.146781...
# 332785    [0.6792511, -0.31961018, -1.1608726, 0.6026232...
# 332786    [-0.37618676, 1.4334834, -0.07109529, -0.27077...
# 332787    [0.7697229, 1.9830147, 1.349007, 1.006025, 2.0...
# Length: 199549, dtype: object

# %%
# Adding the columns back
test_set['srch_id'] = df_test_columns_removed['srch_id']
test_set['prop_id'] = df_test_columns_removed['prop_id']

# %%
test_set.shape
# Out:
# (4959183, 26)

# %%
test_df_sorted = test_set.sort_values(['srch_id', 'prop_id'])
# Add predictions to test set
test_df_sorted['predicted_ranking'] = np.concatenate(predictions.values)

# %%
test_df_sorted.sort_values(['srch_id', 'predicted_ranking'], ascending=[True, False], inplace=True)

# %%
# Select the columns `srch_id` and `prop_id`
result = test_df_sorted[['srch_id', 'prop_id']]
result
# Out:
#          srch_id  prop_id
# 6              1    34263
# 24             1   123675
# 27             1   134992
# 20             1    90385
# 19             1    89466
# ...          ...      ...
# 4959178   332787    32019
# 4959182   332787    99509
# 4959179   332787    33959
# 4959176   332787    22854
# 4959181   332787    94437
#
# [4959183 rows x 2 columns]

# %%
# Export submission file:
result.to_csv('XGRanker_submission_file.csv', index=False)
